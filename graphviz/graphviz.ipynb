# %%
import graphviz

# %%
d = graphviz.Digraph()

# %%
d.edge('helllo', 'world')
d

# %%
s = graphviz.Digraph('abc', graph_attr={'rankdir': 'LR'}, node_attr={'shape': 'record'})

# %%
s.node('apbap', '{<i_jtag>JTAG|<o_apb>APB}')

# %%
s.node('apbic', '{{<i_apb0>APB-0|<i_apb1>APB-1}|APBIC|{<o_apb_0>APB-0|<o_apb_1>APB-1}}')

# %%
s.edges([('apbap:o_apb', 'apbic:i_apb1')])

# %%
s
